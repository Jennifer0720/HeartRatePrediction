# %%
import numpy as np
import pylab
A = 1
H = 1
BU = 0
W = 0

# %%
# initial parameters
n_iter = 50
sz = (n_iter,) # size of array
x = -0.737 # truth value
z = np.random.normal(x, 0.1, size = sz) #observations(normal about x, sigman = 0.1)

Q = 1e-5 # process variance

print sz
# Out:
# (50,)

# %%
# allocate space for arrays
xhat = np.zeros(sz) # estimate of x(n)
P = np.zeros(sz)    # error estimate(n)
xhatminus = np.zeros(sz) # a priori estimate of x
Pminus = np.zeros(sz) # a priori error estimate
K = np.zeros(sz) # gain or blening factor

R = 0.1**2

# %%
# initial guesses
xhat[0] = 0.0
P[0] = 1.0

for k in range(1, n_iter):
    # time update
    xhatminus[k] = xhat[k-1]
    Pminus[k] = P[k-1] + Q
    
    #measurement update
    K[k] = Pminus[k]/(Pminus[k] + R)
    xhat[k] = xhatminus[k]+K[k]*(z[k]-xhatminus[k])
    P[k] = (1-K[k])*Pminus[k]

# %%
pylab.figure()
pylab.plot(z, 'k+', label = 'noisy measurement')
pylab.plot(xhat, 'b-', label = 'a posteri estimate')
pylab.axhline(x, color = 'g', label = 'truth value')
pylab.legend()
pylab.xlabel('Iteration')
pylab.ylabel('Voltage')
# Out:
# Text(0,0.5,u'Voltage')

# %%
pylab.figure()
valid_iter = range(1, n_iter)
pylab.plot(valid_iter, Pminus[valid_iter],label = 'a priori error estimate')
pylab.xlabel('Iteration')
pylab.ylabel('$(Voltage)^2$')
pylab.setp(pylab.gca(),'ylim',[0,.01])  
pylab.show()
